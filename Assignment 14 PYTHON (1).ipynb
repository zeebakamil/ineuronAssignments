# %%
#ASSIGNMENT 14 PYTHON

# %%
# Ans: 1 
#RGBA stands for Red Green Blue and Alpha.

# %%
# Ans:2

# %%
from PIL import Image
cat3_im = Image.open("D:\I neuron\Catdog project\cat03.jpg")
cat3_im.show()
cat3_width,cat3_height = cat3_im.size
print("Cat3 height = ",cat3_height,"Cat3 width = ", cat3_width)
cat3_im.getdata()
import collections
from collections import Counter
pixels = cat3_im.convert('RGBA')
print("\n pixels= ",pixels)
data = pixels.getdata()
print("\n data= ",data)
counts = collections.Counter(data)
print("\n counts= ",counts)
# Out:
# Cat3 height =  1199 Cat3 width =  1200
#
#  pixels=  <PIL.Image.Image image mode=RGBA size=1200x1199 at 0x23967E378B0>
#
#  data=  <ImagingCore object at 0x0000023968F35310>
#
# ...

# %%
# Ans: 4

# %%
cat3_width,cat3_height = cat3_im.size
print("Cat3 height = ",cat3_height,"Cat3 width = ", cat3_width)
# Out:
# Cat3 height =  1199 Cat3 width =  1200

# %%
# Ans:3
# Pillow's function and method take a box tuple argument, which means Pillow is expecting a tuple of four integer cordinates that represent a rectangular region in an image. The four integers are left,Top,Right, Bottom.
#Box tuple includes the left and top cordinates but does not include right and bottom cordinates.

# %%
# Ans: 6

# %%
from PIL import Image
cat3_im = Image.open("D:\I neuron\Catdog project\cat03.jpg")
cat3_im.getdata()

# %%
from PIL import Image
im = Image.new('RGBA', (100, 200), 'Blue')
im.save('BlueImage.png')
im2 = Image.new('RGBA', (20, 20))
im2.save('transparentImage.png')

# %%
#from PIL import Image
#cat3_im = Image.open("D:\I neuron\Catdog project\cat03.jpg")
#croppedIm = cat03Im.crop((335, 345, 565, 560))
#croppedIm.save('cropped.png')

# %%
#Ans:7

# %%
# ImageDraw module contains Pillow’s shape-drawing code.
